# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df1=pd.read_csv('QVI_transaction_data.csv')
df1
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# ...

# %%
print("missing values")
print(df1.isnull().sum())
# Out:
# missing values
# DATE              0
# STORE_NBR         0
# LYLTY_CARD_NBR    0
# TXN_ID            0
# PROD_NBR          0
# PROD_NAME         0
# PROD_QTY          0
# TOT_SALES         0
# dtype: int64

# %%
print("\nDuplicates:")
print(df1.duplicated().sum())
# Out:
# Duplicates:
# 1

# %%
df1.info
# Out:
# <bound method DataFrame.info of          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43605          1            1343     383        61
# 3       43329          2            2373     974        69
# 4       43330          2            2426    1038       108
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                        PROD_NAME  PROD_QTY  TOT_SALES
# 0         Natural Chip        Compny SeaSalt175g         2        6.0
# 1                       CCs Nacho Cheese    175g         3        6.3
# ...

# %%
df1.describe()
# Out:
#                 DATE     STORE_NBR  LYLTY_CARD_NBR        TXN_ID  \
# count  264836.000000  264836.00000    2.648360e+05  2.648360e+05
# mean    43464.036260     135.08011    1.355495e+05  1.351583e+05
# std       105.389282      76.78418    8.057998e+04  7.813303e+04
# min     43282.000000       1.00000    1.000000e+03  1.000000e+00
# 25%     43373.000000      70.00000    7.002100e+04  6.760150e+04
# 50%     43464.000000     130.00000    1.303575e+05  1.351375e+05
# 75%     43555.000000     203.00000    2.030942e+05  2.027012e+05
# max     43646.000000     272.00000    2.373711e+06  2.415841e+06
#
#             PROD_NBR       PROD_QTY      TOT_SALES
# count  264836.000000  264836.000000  264836.000000
# mean       56.583157       1.907309       7.304200
# std        32.826638       0.643654       3.083226
# min         1.000000       1.000000       1.500000
# 25%        28.000000       2.000000       5.400000
# 50%        56.000000       2.000000       7.400000
# ...

# %%
data=df1['LYLTY_CARD_NBR'],df1['TXN_ID'],df1['PROD_NBR'],df1['PROD_QTY'],df1['TOT_SALES']


plt.figure(figsize=(10, 6))
plt.boxplot(data, labels=['LYLTY_CARD_NBR', 'TXN_ID', 'PROD_NBR', 'PROD_QTY', 'TOT_SALES'])
plt.title('Box Plot of Multiple Columns')
plt.ylabel('Values')
plt.xlabel('Columns')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add grid lines for better visualization
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
df2=pd.read_csv("QVI_purchase_behaviour.csv")
df2
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
print(df2.isnull().sum())
# Out:
# LYLTY_CARD_NBR      0
# LIFESTAGE           0
# PREMIUM_CUSTOMER    0
# dtype: int64

# %%
print("\nDuplicates:")
print(df2.duplicated().sum())
# Out:
# Duplicates:
# 0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72637 entries, 0 to 72636
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LYLTY_CARD_NBR    72637 non-null  int64
#  1   LIFESTAGE         72637 non-null  object
#  2   PREMIUM_CUSTOMER  72637 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.7+ MB

# %%
df=pd.merge(df1,df2,on='LYLTY_CARD_NBR')
df.to_csv('merged_data.csv', index=False)

# %%
df
# Out:
#          DATE  STORE_NBR  LYLTY_CARD_NBR  TXN_ID  PROD_NBR  \
# 0       43390          1            1000       1         5
# 1       43599          1            1307     348        66
# 2       43414          1            1307     346        96
# 3       43533          1            1307     347        54
# 4       43605          1            1343     383        61
# ...       ...        ...             ...     ...       ...
# 264831  43533        272          272319  270088        89
# 264832  43325        272          272358  270154        74
# 264833  43410        272          272379  270187        51
# 264834  43461        272          272379  270188        42
# 264835  43365        272          272380  270189        74
#
#                                       PROD_NAME  PROD_QTY  TOT_SALES  \
# 0        Natural Chip        Compny SeaSalt175g         2        6.0
# 1                      CCs Nacho Cheese    175g         3        6.3
# ...

# %%
from IPython.display import FileLink


FileLink(r'merged_data.csv')
# Out:
# C:\Users\Asus\merged_data.csv

# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('merged_data.csv')

# Convert DataFrame to Excel
excel_filename = 'merge_file.xlsx'
df.to_excel(excel_filename, index=False)

# Provide the link to download the file in Jupyter Notebook
from IPython.display import FileLink
FileLink(r'merge_file.xlsx')
# Out:
# C:\Users\Asus\merge_file.xlsx

# %%
import pandas as pd


data = pd.read_csv("merged_data.csv")

# %%
# Analyze total sales by customer segments
total_sales_by_customer = data.groupby('PREMIUM_CUSTOMER')['TOT_SALES'].sum()
print("Total Sales by Customer Segment:")
print(total_sales_by_customer)
# Out:
# Total Sales by Customer Segment:
# PREMIUM_CUSTOMER
# Budget        676211.55
# Mainstream    750744.50
# Premium       507458.95
# Name: TOT_SALES, dtype: float64

# %%
# Calculate the total sales for each premium customer category
total_sales_by_customer = data.groupby('PREMIUM_CUSTOMER')['TOT_SALES'].sum().reset_index()

# Plot the grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='PREMIUM_CUSTOMER', y='TOT_SALES', data=total_sales_by_customer)
plt.xlabel('Premium Customer')
plt.ylabel('Total Sales')
plt.title('Total Sales by Premium Customer')
plt.show()

# %%
# Analyze total sales by lifestage
total_sales_by_lifestage = data.groupby('LIFESTAGE')['TOT_SALES'].sum()
print("Total Sales by Lifestage:")
print(total_sales_by_lifestage)
# Out:
# Total Sales by Lifestage:
# LIFESTAGE
# MIDAGE SINGLES/COUPLES    184751.30
# NEW FAMILIES               50433.45
# OLDER FAMILIES            353767.20
# OLDER SINGLES/COUPLES     402426.75
# RETIREES                  366470.90
# YOUNG FAMILIES            316160.10
# YOUNG SINGLES/COUPLES     260405.30
# Name: TOT_SALES, dtype: float64

# %%
# Calculate the total sales for each premium customer category

# Calculate total sales by lifestage
total_sales_by_lifestage = data.groupby('LIFESTAGE')['TOT_SALES'].sum().reset_index()

# Plot the grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='LIFESTAGE', y='TOT_SALES', data=total_sales_by_lifestage)
plt.xlabel('Lifestage')
plt.ylabel('Total Sales')
plt.title('Total Sales by Lifestage')
plt.xticks(rotation=45)
plt.show()

# %%
# Analyze average sales per transaction
average_sales_per_transaction = data['TOT_SALES'].mean()
print("Average Sales per Transaction:", average_sales_per_transaction)
# Out:
# Average Sales per Transaction: 7.304199580116094

# %%
# Analyze most purchased product
most_purchased_product = data['PROD_NAME'].mode()[0]
print("Most Purchased Product:", most_purchased_product)
# Out:
# Most Purchased Product: Kettle Mozzarella   Basil & Pesto 175g

# %%
correlation_matrix = data[['PROD_QTY', 'TOT_SALES']].corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#            PROD_QTY  TOT_SALES
# PROD_QTY   1.000000   0.715307
# TOT_SALES  0.715307   1.000000

# %%
average_sales_by_segment = data.groupby('PREMIUM_CUSTOMER')['TOT_SALES'].mean()
print("Average Sales per Transaction by Customer Segment:")
print(average_sales_by_segment)
# Out:
# Average Sales per Transaction by Customer Segment:
# PREMIUM_CUSTOMER
# Budget        7.258838
# Mainstream    7.361106
# Premium       7.281556
# Name: TOT_SALES, dtype: float64

# %%
total_sales_by_product = data.groupby('PROD_NAME')['TOT_SALES'].sum().sort_values(ascending=False)
print("Total Sales by Product Name:")
print(total_sales_by_product)
# Out:
# Total Sales by Product Name:
# PROD_NAME
# Dorito Corn Chp     Supreme 380g            40352.0
# Smiths Crnkle Chip  Orgnl Big Bag 380g      36367.6
# Smiths Crinkle Chips Salt & Vinegar 330g    34804.2
# Kettle Mozzarella   Basil & Pesto 175g      34457.4
# Smiths Crinkle      Original 330g           34302.6
#                                              ...
# WW Crinkle Cut      Chicken 175g             4702.2
# Sunbites Whlegrn    Crisps Frch/Onin 90g     4600.2
# WW Crinkle Cut      Original 175g            4532.2
# Woolworths Mild     Salsa 300g               4234.5
# Woolworths Medium   Salsa 300g               4050.0
# Name: TOT_SALES, Length: 114, dtype: float64

# %%
total_sales_by_product = data.groupby('PROD_NAME')['TOT_SALES'].sum()

# Get the product name with the highest total sales
top_product_name = total_sales_by_product.idxmax()

# Get the corresponding total sales value
top_total_sales = total_sales_by_product.max()

print("Product with the highest total sales:", top_product_name)
print("Total sales for this product:", top_total_sales)
# Out:
# Product with the highest total sales: Dorito Corn Chp     Supreme 380g
# Total sales for this product: 40352.0

# %%
total_sales_by_product = data.groupby('PROD_NAME')['TOT_SALES'].sum().reset_index()
top_10_products = total_sales_by_product.nlargest(10, 'TOT_SALES')

plt.figure(figsize=(10, 12))
sns.barplot(x='TOT_SALES', y='PROD_NAME',data=top_10_products, orient='h')
plt.xlabel('Total Sales')
plt.ylabel('Product Name')
plt.title('Total Sales by Product')
plt.show()

# %%
# Example: Segment customers based on lifestage and premium customer
segmented_customers = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER']).size().unstack(fill_value=0)
print("Customer Segmentation:")
print(segmented_customers)
# Out:
# Customer Segmentation:
# PREMIUM_CUSTOMER        Budget  Mainstream  Premium
# LIFESTAGE
# MIDAGE SINGLES/COUPLES    5020       11874     8216
# NEW FAMILIES              3005        2325     1589
# OLDER FAMILIES           23160       14244    11192
# OLDER SINGLES/COUPLES    18407       18318    17754
# RETIREES                 15201       21466    13096
# YOUNG FAMILIES           19122       12907    11563
# YOUNG SINGLES/COUPLES     9242       20854     6281

# %%
# Calculate total sales by lifestage
segmented_customers = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER']).size().reset_index()


# Create the clustered bar plot
plt.figure(figsize=(12, 8))
sns.countplot(data=data, x='LIFESTAGE', hue='PREMIUM_CUSTOMER', palette='husl')
plt.xlabel('Lifestage')
plt.ylabel('Count')
plt.title('Customer Segmentation by Lifestage and Premium Customer')
plt.xticks(rotation=45)
plt.legend(title='Premium Customer')
plt.show()

# %%
plt.figure(figsize=(10, 6))
heatmap_data = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER']).size().unstack()
sns.heatmap(heatmap_data, cmap='Blues', annot=True, fmt='d')
plt.xlabel('Premium Customer')
plt.ylabel('Lifestage')
plt.title('Count of Lifestage by Premium Customer')
plt.show()

# %%
# Group the data by 'PROD_NAME' and sum the 'PROD_QTY' for each product
product_quantity = data.groupby('PROD_NAME')['PROD_QTY'].sum()

# Find the product with the highest total quantity sold
most_sold_product = product_quantity.idxmax()
total_quantity_sold = product_quantity.max()

print("Product with the most quantity sold:", most_sold_product)
print("Total quantity sold:", total_quantity_sold)
# Out:
# Product with the most quantity sold: Dorito Corn Chp     Supreme 380g
# Total quantity sold: 6509

# %%
# Group the data by 'PROD_NAME' and sum the 'PROD_QTY' for each product
product_quantity = data.groupby('PROD_NAME')['PROD_QTY'].sum()

# Find the product with the highest total quantity sold
mostless_sold_product = product_quantity.idxmin()
total_quantity_sold = product_quantity.min()

print("Product with the min quantity sold:", mostless_sold_product)
print("Total quantity sold:", total_quantity_sold)
# Out:
# Product with the min quantity sold: French Fries Potato Chips 175g
# Total quantity sold: 2643

# %%
# Convert 'DATE' column to datetime
data['DATE'] = pd.to_datetime(data['DATE'])

# Group by date and calculate total sales
total_sales_by_date = data.groupby('DATE')['TOT_SALES'].sum()

# Plot total sales trend over time
plt.figure(figsize=(15,5))
total_sales_by_date.plot()
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.title('Total Sales Trend over Time')
plt.show()

# %%
# Group by both 'LIFESTAGE' and 'PREMIUM_CUSTOMER' and calculate the sum of 'TOT_SALES' for each combination
segmented_sales = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum()


segmented_sales
# Out:
# LIFESTAGE               PREMIUM_CUSTOMER
# MIDAGE SINGLES/COUPLES  Budget               35514.80
#                         Mainstream           90803.85
#                         Premium              58432.65
# NEW FAMILIES            Budget               21928.45
#                         Mainstream           17013.90
#                         Premium              11491.10
# OLDER FAMILIES          Budget              168363.25
#                         Mainstream          103445.55
#                         Premium              81958.40
# OLDER SINGLES/COUPLES   Budget              136769.80
#                         Mainstream          133393.80
#                         Premium             132263.15
# RETIREES                Budget              113147.80
#                         Mainstream          155677.05
#                         Premium              97646.05
# YOUNG FAMILIES          Budget              139345.85
#                         Mainstream           92788.75
# ...

# %%
max_sales = segmented_sales.max()
max_sales_index = segmented_sales.idxmax()

print("Maximum total sales:", max_sales)
print("Combination with maximum total sales:", max_sales_index)
# Out:
# Maximum total sales: 168363.25
# Combination with maximum total sales: ('OLDER FAMILIES', 'Budget')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert the segmented sales data to a DataFrame
segmented_sales = data.groupby(['LIFESTAGE', 'PREMIUM_CUSTOMER'])['TOT_SALES'].sum().reset_index()


# Create a pivot table to reshape the data for heatmap
pivot_table = segmented_sales_df.pivot(index='LIFESTAGE', columns='PREMIUM_CUSTOMER', values='TOT_SALES')

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Total Sales by Lifestage and Premium Customer')
plt.xlabel('Premium Customer')
plt.ylabel('Lifestage')
plt.show()

# %%
#Top Selling Product:

The product Dorito Corn Chp Supreme 380g stands out as the top-selling item.
It recorded a whopping sales figure of 40,352.00, with 6,509 bags sold.

#least selling product 

Product with the min quantity sold: French Fries Potato Chips 175g

#Sales by Life Stage and Premium Customer:

In the Budget segment,: 
    older families contributed significantly to sales, with total spending reaching 168,363.25.
    
Within the Mainstream segment,:
    young singles/couples exhibited substantial spending, totaling 157,621.60.
    Additionally, retirees in the Mainstream category also contributed significantly, with total sales amounting to 155,677.05.

In the Premium segment,:
    older singles/couples showed strong purchasing behavior, with total sales reaching 132,263.15.

#Consumer Preferences:

Young, middle-aged, and mainstream individuals and couples demonstrated a propensity to pay more for each bag of chips.

#Sales Peak in January 2019:

 Sales were at their peak in January 2019-01
